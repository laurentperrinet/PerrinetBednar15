# %% [markdown]
# # installation instructions
#
# All scripts use the python programming language. On Linux, this is preinstalled and straightforward to install. On MacOs, I recommend using [HomeBrew](http://brew.sh), and a full python toolchain is easily installable using configuration scripts asuch as [this one](https://github.com/laurentperrinet/config-scripts/blob/master/osx_brew_python.sh). The following libraries are necessary to run the notebooks :

# %% [markdown]
# ## numpy and scikit-learn
#
# All algorithms are using extensively the `numpy` library.
#
# For the classification we use the SVM package implemented in `scikit-learn` and which corresponds to the classical `libsvm` library. As  `scikit-learn` depends on `numpy`, it is sufficient to install :

# %%
# !pip3 install -U scikit-learn

# %% [markdown]
# ## SparseEdges
#
# The sparse coding is performed by the [SparseEdges](https://github.com/laurentperrinet/SparseEdges) library which is documented at https://pythonhosted.org/SparseEdges.
#
# It depends on a multi-resolution approach implemented in the [LogGabor](https://github.com/laurentperrinet/LogGabor) package and documented at https://pythonhosted.org/LogGabor and uses the image processing tools from the [SLIP](https://github.com/laurentperrinet/SLIP) library.

# %%
# !pip3 install git+https://github.com/bicv/SLIP.git
# !pip3 install git+https://github.com/bicv/LogGabor.git
# !pip3 install git+https://github.com/bicv/SparseEdges.git

# %% [markdown]
# # jupyter
#
# To install the notebook utility use:

# %%
# !pip3 install jupyter

# %% [markdown]
# and then to start it, run in a terminal:
#
# ``
# jupyter notebook
# ``
#
# Another solution is to use the [nteract](https://github.com/nteract) software:

# %%
# !brew cask install nteract
# Out:
# Warning: A Cask for nteract is already installed.
#
# To re-install nteract, run:
#   brew cask reinstall nteract

# %% [markdown]
# # matplotlib
#
# Most plot are done with the `matplotlib` library:

# %%
# !pip3 install -U matplotlib

# %% [markdown]
# # seaborn
#
#
# For the results' bar plots, we use the `seaborn` utility:

# %%
# !pip3 install -U seaborn pandas

# %% [markdown]
# ## tikzmagic
#
# I use the tikmagic described in http://blog.invibe.net/posts/2015-01-20-using-tikzmagic.html
# This is an extension for the jupyter notebooks to handle TIKZ plots interactively: check out https://github.com/robjstan/tikzmagic :

# %%
#!pip3 install git+git://github.com/laurentperrinet/ipython_magics
# !pip3 install git+git://github.com/robjstan/tikzmagic.git
#!pip3 install git+git://github.com/mkrphys/ipython-tikzmagic.git
# Out:
# Collecting git+git://github.com/robjstan/tikzmagic.git
#   Cloning git://github.com/robjstan/tikzmagic.git to /private/var/folders/px/n031whw95_39ccwg0wqwt5jw0000gn/T/pip-ihdvmr6n-build
# Requirement already satisfied: IPython in /usr/local/lib/python3.6/site-packages (from tikzmagic==1.0.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/site-packages (from IPython->tikzmagic==1.0.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/site-packages (from traitlets>=4.2->IPython->tikzmagic==1.0.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from traitlets>=4.2->IPython->tikzmagic==1.0.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->IPython->tikzmagic==1.0.5)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/site-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython->tikzmagic==1.0.5)
# Requirement already satisfied: parso==0.1.0 in /usr/local/lib/python3.6/site-packages (from jedi>=0.10->IPython->tikzmagic==1.0.5)
# Installing collected packages: tikzmagic
#   Running setup.py install for tikzmagic ... done
# Successfully installed tikzmagic-1.0.5

# %%
import tikzmagic

# %%
# %%tikz -p 'tkz-euclide' -x '\usetkzobj{{all}}' --debug
#
# \draw[thick, color=gray,->] (-15,0) -- (12,0) node[right] {\textcolor{black}{$x$}};
# \draw[thick, color=gray, ->] (0,-6) -- (0,12) node[above] {\textcolor{black}{$y$}};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=left:{$C_1$}] (C1) at (-6,4) {};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=right:{$C_2$}] (C2) at (2,1) {};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=above:{$~~A$}] (A) at (15/73,478/73) {};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=below:{$B~$}] (B) at (-3,-2) {};
# \node at (-14, 4) {$K_1$};
# \node at (9, -1) {$K_2$};
# \draw[gray] (C1) -- (C2);
# \draw[blue] (C1) --(B);
# \draw[red] (C2) --(B);
# \draw[blue] (C1) --(A);
# \draw[red] (C2) --(A);
# \draw (C1) circle (6.7082);
# \draw (C2) circle (3.83095);
# \tkzMarkSegment[color=blue,pos=.5,mark=||](C1,B);
# \tkzMarkSegment[color=red,pos=.5,mark=|](B,C2);
# \tkzMarkSegment[color=blue,pos=.5,mark=||](C1,A);
# \tkzMarkSegment[color=red,pos=.5,mark=|](A,C2);
# \tkzMarkRightAngle[size=0.7](C1,A,C2);
# \tkzMarkRightAngle[size=0.7](C1,B,C2);
# Out:
# \documentclass[tikz,border=4]{standalone}
# \usepackage{tikz,tkz-euclide}
# \usetikzlibrary{}
# \usetkzobj{all}
# \begin{document}
# \begin{tikzpicture}
# \draw[thick, color=gray,->] (-15,0) -- (12,0) node[right] {\textcolor{black}{$x$}};
# \draw[thick, color=gray, ->] (0,-6) -- (0,12) node[above] {\textcolor{black}{$y$}};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=left:{$C_1$}] (C1) at (-6,4) {};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=right:{$C_2$}] (C2) at (2,1) {};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=above:{$~~A$}] (A) at (15/73,478/73) {};
# \node[circle,fill=black,inner sep=0pt,minimum size=3pt,label=below:{$B~$}] (B) at (-3,-2) {};
# \node at (-14, 4) {$K_1$};
# \node at (9, -1) {$K_2$};
# \draw[gray] (C1) -- (C2);
# \draw[blue] (C1) --(B);
# \draw[red] (C2) --(B);
# \draw[blue] (C1) --(A);
# \draw[red] (C2) --(A);
# \draw (C1) circle (6.7082);
# \draw (C2) circle (3.83095);
# \tkzMarkSegment[color=blue,pos=.5,mark=||](C1,B);
# \tkzMarkSegment[color=red,pos=.5,mark=|](B,C2);
# \tkzMarkSegment[color=blue,pos=.5,mark=||](C1,A);
# \tkzMarkSegment[color=red,pos=.5,mark=|](A,C2);
# \tkzMarkRightAngle[size=0.7](C1,A,C2);
# \tkzMarkRightAngle[size=0.7](C1,B,C2);\end{tikzpicture}
# \end{document}

# %% [markdown]
# ## additional libraries
#
# I use `convert` to code PDF figures into images :

# %%
# !brew install imagemagick

# %% [markdown]
# ## version control

# %%
# !git add 0\ installation.ipynb
# !git status
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 6 commits.
#   (use "git push" to publish your local commits)
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   0 installation.ipynb

# %%
# !git commit -m' adding a notebook describing the installation of libraries ' 
#! git push
# Out:
# [master 53073fe]  adding a notebook describing the installation of libraries
#  1 file changed, 126 insertions(+), 33 deletions(-)
